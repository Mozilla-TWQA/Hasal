# %%
import pandas as pd
import numpy as np
import json 
from pprint import pprint
import matplotlib.pyplot as plt

with open('/Users/bobby/Documents/github/Hasal/tools/result_GDocs_AIL.json') as data_file:
    data = json.load(data_file)
    d = pd.DataFrame(data)[['test_chrome_gdoc_real_input_latency',
                            'test_firefox_gdoc_real_input_latency',
                            'test_chrome_gdoc_page10_typea',
                            'test_firefox_gdoc_page10_typea']]  
    dil = d.loc[['avg_time',
            'max_time', 
            'med_time',
            'min_time',
            'std_dev'], :]

dil
# Out:
#          test_chrome_gdoc_real_input_latency  \
# avg_time                             59.4444
# max_time                             83.3333
# med_time                             66.6667
# min_time                                  50
# std_dev                              9.31281
#
#          test_firefox_gdoc_real_input_latency test_chrome_gdoc_page10_typea  \
# avg_time                              95.5556                       48.3804
# max_time                              116.667                       66.6667
# med_time                                  100                            50
# min_time                              83.3333                       33.3333
# std_dev                               10.4822                       10.8238
#
#          test_firefox_gdoc_page10_typea
# avg_time                        110.556
# max_time                        133.333
# med_time                        108.333
# min_time                            100
# std_dev                          11.772

# %%
runtime = pd.DataFrame([pd.DataFrame(d[c]['time_list'])['run_time'] for c in d]).T
runtime.columns = d.columns
runtime

#time_chrome = pd.DataFrame(d['test_chrome_gdoc_real_input_latency']['time_list'])
#time_firefox = pd.DataFrame(d['test_firefox_gdoc_real_input_latency']['time_list'])
# Out:
#     test_chrome_gdoc_real_input_latency  test_firefox_gdoc_real_input_latency  \
# 0                             50.000000                             83.333333
# 1                             50.000000                             83.333333
# 2                             50.000000                             83.333333
# 3                             50.000000                             83.333333
# 4                             50.000000                             83.333333
# 5                             50.000000                             83.333333
# 6                             50.000000                             83.333333
# 7                             50.000000                             83.333333
# 8                             50.000000                             83.333333
# 9                             50.000000                             83.333333
# 10                            50.000000                             83.333333
# 11                            50.000000                            100.000000
# 12                            50.000000                            100.000000
# 13                            50.000000                            100.000000
# 14                            66.666667                            100.000000
# 15                            66.666667                            100.000000
# 16                            66.666667                            100.000000
# 17                            66.666667                            100.000000
# 18                            66.666667                            100.000000
# 19                            66.666667                            100.000000
# 20                            66.666667                            100.000000
# 21                            66.666667                            100.000000
# 22                            66.666667                            100.000000
# 23                            66.666667                            100.000000
# 24                            66.666667                            100.000000
# 25                            66.666667                            100.000000
# 26                            66.666667                            100.000000
# 27                            66.666667                            116.666667
# 28                            66.666667                            116.666667
# 29                            83.333333                            116.666667
#
#     test_chrome_gdoc_page10_typea  test_firefox_gdoc_page10_typea
# 0                       33.333333                      100.000000
# 1                       33.333333                      100.000000
# 2                       33.333333                      100.000000
# 3                       33.333333                      100.000000
# 4                       33.333333                      100.000000
# 5                       33.333333                      100.000000
# 6                       33.333333                      100.000000
# 7                       33.898305                      100.000000
# 8                       50.000000                      100.000000
# 9                       50.000000                      100.000000
# 10                      50.000000                      100.000000
# 11                      50.000000                      100.000000
# 12                      50.000000                      100.000000
# 13                      50.000000                      100.000000
# 14                      50.000000                      100.000000
# 15                      50.000000                      116.666667
# 16                      50.000000                      116.666667
# 17                      50.000000                      116.666667
# 18                      50.000000                      116.666667
# 19                      50.000000                      116.666667
# 20                      50.000000                      116.666667
# 21                      50.000000                      116.666667
# 22                      50.000000                      116.666667
# 23                      50.000000                      116.666667
# 24                      50.847458                      116.666667
# 25                      66.666667                      116.666667
# 26                      66.666667                      133.333333
# 27                      66.666667                      133.333333
# 28                      66.666667                      133.333333
# 29                      66.666667                      133.333333

# %%
runtime.quantile([0.01, 0.99], interpolation='nearest')
# Out:
#       test_chrome_gdoc_real_input_latency  \
# 0.01                            50.000000
# 0.99                            83.333333
#
#       test_firefox_gdoc_real_input_latency  test_chrome_gdoc_page10_typea  \
# 0.01                             83.333333                      33.333333
# 0.99                            116.666667                      66.666667
#
#       test_firefox_gdoc_page10_typea
# 0.01                      100.000000
# 0.99                      133.333333

# %%
runtime.describe()
# Out:
#        test_chrome_gdoc_real_input_latency  \
# count                            30.000000
# mean                             59.444444
# std                               9.472013
# min                              50.000000
# 25%                              50.000000
# 50%                              66.666667
# 75%                              66.666667
# max                              83.333333
#
#        test_firefox_gdoc_real_input_latency  test_chrome_gdoc_page10_typea  \
# count                             30.000000                      30.000000
# mean                              95.555556                      48.380414
# std                               10.661397                      11.008812
# min                               83.333333                      33.333333
# 25%                               83.333333                      37.923729
# 50%                              100.000000                      50.000000
# 75%                              100.000000                      50.000000
# max                              116.666667                      66.666667
#
#        test_firefox_gdoc_page10_typea
# count                       30.000000
# mean                       110.555556
# std                         11.973257
# min                        100.000000
# 25%                        100.000000
# 50%                        108.333333
# 75%                        116.666667
# max                        133.333333

# %%
runtime.plot.hist(bins=20, histtype='bar', color=['green','orange'])
runtime.plot.box()
plt.show()
